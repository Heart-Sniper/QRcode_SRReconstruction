# %%
! torchrun \
    --standalone \
    --nnodes=1 \
    D:\Project\QRCodeClarityRestoration\CodeFormer\train.py \
    -opt D:\Project\QRCodeClarityRestoration\CodeFormer\options\VQGAN_512_ds32_nearest_stage1.yml \
    --launcher pytorch
# Out:
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# Loading model from: d:\Program\Anaconda\envs\QRcode\Lib\site-packages\lpips\weights\v0.1\vgg.pth
# NOTE: Redirects are currently not supported in Windows or MacOs.
# master_addr is only used for static rdzv_backend and when rdzv_endpoint is not specified.
# 2023-12-28 16:47:23,808 INFO:
#                 ____                _       _____  ____
#                / __ ) ____ _ _____ (_)_____/ ___/ / __ \
#               / __  |/ __ `// ___// // ___/\__ \ / /_/ /
#              / /_/ // /_/ /(__  )/ // /__ ___/ // _, _/
#             /_____/ \__,_//____//_/ \___//____//_/ |_|
#      ______                   __   __                 __      __
#     / ____/____   ____   ____/ /  / /   __  __ _____ / /__   / /
#    / / __ / __ \ / __ \ / __  /  / /   / / / // ___// //_/  / /
#   / /_/ // /_/ // /_/ // /_/ /  / /___/ /_/ // /__ / /<    /_/
#   \____/ \____/ \____/ \____/  /_____/\____/ \___//_/|_|  (_)
#
# ...
